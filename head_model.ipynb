# %%
import mne
from mne.datasets import sample

data_path = sample.data_path()

# the raw file containing the channel location + types
sample_dir = data_path / "MEG" / "sample"
raw_fname = sample_dir / "sample_audvis_raw.fif"
# The paths to Freesurfer reconstructions
subjects_dir = data_path / "subjects"
subject = "sample"
# Out:
# Using default location ~/mne_data for sample...
# Creating ~/mne_data
# Downloading file 'MNE-sample-data-processed.tar.gz' from 'https://osf.io/86qa2/download?version=6' to '/Users/yanranli/mne_data'.
# 100%|█████████████████████████████████████| 1.65G/1.65G [00:00<00:00, 1.79TB/s]
# Untarring contents of '/Users/yanranli/mne_data/MNE-sample-data-processed.tar.gz' to '/Users/yanranli/mne_data'
# Attempting to create new mne-python configuration file:
# /Users/yanranli/.mne/mne-python.json
# Download complete in 02m03s (1576.2 MB)

# %%
plot_bem_kwargs = dict(
    subject=subject,
    subjects_dir=subjects_dir,
    brain_surfaces="white",
    orientation="coronal",
    slices=[50, 100, 150, 200],
)

mne.viz.plot_bem(**plot_bem_kwargs)
# Out:
# Using surface: /Users/yanranli/mne_data/MNE-sample-data/subjects/sample/bem/inner_skull.surf
# Using surface: /Users/yanranli/mne_data/MNE-sample-data/subjects/sample/bem/outer_skull.surf
# Using surface: /Users/yanranli/mne_data/MNE-sample-data/subjects/sample/bem/outer_skin.surf
# /opt/anaconda3/envs/mne/lib/python3.12/site-packages/mne/viz/utils.py:165: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNEFigure size 780x260.5 with 4 Axes>
# <MNEFigure size 780x260.5 with 4 Axes>

# %%
# The transformation file obtained by coregistration
trans = sample_dir / "sample_audvis_raw-trans.fif"

info = mne.io.read_info(raw_fname)
# Here we look at the dense head, which isn't used for BEM computations but
# is useful for coregistration.
mne.viz.plot_alignment(
    info,
    trans,
    subject=subject,
    dig=True,
    meg=["helmet", "sensors"],
    subjects_dir=subjects_dir,
    surfaces="head-dense",
)
# Out:
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
# Using pyvistaqt 3d backend.
#
# Using lh.seghead for head surface.
# Getting helmet for system 306m
# Channel types::	grad: 203, mag: 102, eeg: 59
